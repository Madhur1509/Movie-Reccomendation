# %%
import pandas as pd

# %%
import numpy as np

# %%
def get_title_from_index(index):
    return df[df.index == index]["title"].values[0]

# %%
def get_index_from_title(title):
    return df[df.title == title]["index"].values[0]

# %%
df = pd.read_csv (r"C:\Users\1\Downloads\movie_dataset.csv")

# %%
df.drop(['budget' , 'homepage' , 'id', 'original_language' , 'overview'] , axis=1)
# Out:
#       index                                    genres  \
# 0         0  Action Adventure Fantasy Science Fiction
# 1         1                  Adventure Fantasy Action
# 2         2                    Action Adventure Crime
# 3         3               Action Crime Drama Thriller
# 4         4          Action Adventure Science Fiction
# ...     ...                                       ...
# 4798   4798                     Action Crime Thriller
# 4799   4799                            Comedy Romance
# 4800   4800             Comedy Drama Romance TV Movie
# 4801   4801
# 4802   4802                               Documentary
#
#                                                keywords  \
# 0     culture clash future space war space colony so...
# 1     ocean drug abuse exotic island east india trad...
# 2            spy based on novel secret agent sequel mi6
# 3     dc comics crime fighter terrorist secret ident...
# 4     based on novel mars medallion space travel pri...
# ...

# %%
features = ['keywords', 'genres' , 'cast' , 'director']

# %%
for feature in features:
    df[feature] = df[feature].fillna('')

# %%
def combine_features(row):
    return str(row['keywords']) + " " + str(row['genres']) + " " + str(row['cast']) + " " + str(row['director'])

# %%
df["combined_features"] = df.apply(combine_features,axis=1)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()

# %%
count_matrix = cv.fit_transform(df["combined_features"])

# %%
cosine_sim = cosine_similarity(count_matrix)

# %%
movie_user_likes = "Aliens"

# %%
movie_index = get_index_from_title(movie_user_likes)

# %%
similar_movies = list(enumerate(cosine_sim[movie_index]))

# %%
sorted_similar_movies = sorted(similar_movies,key=lambda x:x[1],reverse=True)

# %%
i=0
for movie in sorted_similar_movies:
    print(get_title_from_index(movie[0]))
    i=i+1
    if i>10:
        break
# Out:
# Aliens
# The Terminator
# Alien
# Avatar
# The Box
# Alien³
# Jason X
# The One
# The Abyss
# Alien: Resurrection
# Terminator 2: Judgment Day
